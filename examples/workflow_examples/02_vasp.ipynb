# %% [markdown]
# ## VASP calculation

# %% [markdown]
# Read in an existing calculation to pyiron. Can also be a calculation done within pyiron

# %%
from atomrdf import KnowledgeGraph, System
from pyiron_atomistics import Project

# %%
pr = Project('wf3d')

# %% [markdown]
# Import the finished calculation; this can be ignored if the calculation is performed with pyiron|

# %%
pr.import_single_calculation('fccSi', copy_raw_files=True)
# Out:
# fccSi fccSi
# The job exists already - skipped!

# %%
pr.job_table()
# Out:
#     id    status chemicalformula    job  subjob projectpath  \
# 0  190  finished              Si  fccSi  /fccSi        None
#
#                                                                                       project  \
# 0  /mnt/c/Users/menon/Documents/repos/projects-iuc17/atomRDF/examples/workflow_examples/wf3d/
#
#                    timestart timestop totalcputime          computer hamilton  \
# 0 2024-05-06 19:58:56.392437     None         None  pyiron@cmleo26#1     Vasp
#
#   hamversion parentid masterid
# 0       None     None     None

# %%
job = pr.load('fccSi')

# %%
kg = KnowledgeGraph()

# %%
kg.add_workflow(job, workflow_environment='pyiron')
# Out:
# /home/srmnitc/miniconda3/envs/workflow-rdf/lib/python3.11/site-packages/atomrdf/graph.py:369: UserWarning: asmo:hasValue has a range with unspecified datatype!
#   warnings.warn(f"{triple[1].name} has a range with unspecified datatype!")

# %%
kg.visualise(workflow_view=True, layout='dot')
