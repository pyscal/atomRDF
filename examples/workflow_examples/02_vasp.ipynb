# %% [markdown]
# ## VASP calculation

# %% [markdown]
# Read in an existing calculation to pyiron. Can also be a calculation done within pyiron

# %%
from atomrdf import KnowledgeGraph, System
from pyiron_atomistics import Project

# %%
pr = Project('wfx')

# %% [markdown]
# Import the finished calculation; this can be ignored if the calculation is performed with pyiron|

# %%
pr.import_single_calculation('fccSi', copy_raw_files=True)
# Out:
# fccSi fccSi
# job was stored with the job ID  455

# %%
pr.job_table()
# Out:
#     id    status chemicalformula    job  subjob projectpath  \
# 0  455  finished              Si  fccSi  /fccSi        None
#
#                                                                                      project  \
# 0  /mnt/c/Users/menon/Documents/repos/projects-iuc17/atomRDF/examples/workflow_examples/wfx/
#
#                    timestart timestop totalcputime          computer hamilton  \
# 0 2024-05-08 16:17:18.526710     None         None  pyiron@cmleo26#1     Vasp
#
#   hamversion parentid masterid
# 0       None     None     None

# %%
job = pr.load('fccSi')

# %%
kg = KnowledgeGraph()

# %%
kg.add_workflow(job, workflow_environment='pyiron')

# %%
kg.visualise(workflow_view=True, layout='dot')

# %%
kg.terms.calculation
# Out:
# DensityFunctionalTheoryMethod, GeneralizedGradientApproximation, HybridFunctional, LocalDensityApproximation, MetaGeneralizedGradientApproximation, ExchangeCorrelationEnergyFunctional, HybridGeneralizedGradientApproximation, HybridMetaGeneralizedGradientApproximation, hasXCFunctional
