# %% [markdown]
# # Creating Grain Boundaries

# %% [markdown]
# In this notebook, creation and querying of GBs are discussed. These features are still under active development.

# %%
from atomrdf import KnowledgeGraph
import atomrdf.build as build

from ase.visualize import view

# %%
kg = KnowledgeGraph()

# %% [markdown]
# We start by creating a $\Sigma 5 (3 \bar{1} 0)$

# %%
struct_gb_1 = build.defect.grain_boundary(axis=[0,0,1], 
                        sigma=5, 
                        gb_plane=[3, -1, 0],
                        element='Fe',
                        graph=kg)

# %% [markdown]
# We can visualise the structure

# %%
view(struct_gb_1, viewer='x3d')
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 36.302947538732994">
#     <group/>
#   </viewpoint>
#   <transform translation="-9.075736884683248 -4.537868442341624 -1.4349999999999998">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 18.151473769366497 0.0 1.1114572125730911e-15 18.151473769366497 9.075736884683248 1.6671858188596366e-15 -5.557286062865456e-16 9.075736884683248 5.557286062865456e-16 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 2.8699999999999997">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 18.151473769366497 0.0 1.1114572125730911e-15 18.151473769366497 9.075736884683248 1.6671858188596366e-15 -5.557286062865456e-16 9.075736884683248 5.557286062865456e-16 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 18.151473769366497 0.0 1.1114572125730911e-15 18.151473769366497 0.0 2.870000000000001 0.0 0.0 2.8699999999999997 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="-5.557286062865456e-16 9.075736884683248 5.557286062865456e-16">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 18.151473769366497 0.0 1.1114572125730911e-15 18.151473769366497 0.0 2.870000000000001 0.0 0.0 2.8699999999999997 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="0.0 0.0 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.878 0.4 0.2"/>
#             </appearance>
#             <sphere radius="1.32"/>
#           </shape>
#         </transform>
#         <transform translation="2.7227210654049743 0.9075736884683246 2.2229144251461833e-16">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.878 0.4 0.2"/>
#             </appearance>
#             <sphere radius="1.32"/>
#           </shape>
#         </transform>
#         <transform translation="1.8151473769366497 3.630294753873299 3.3343716377192744e-16">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.878 0.4 0.2"/>
#             </appearance>
#             <sphere radius="1.32"/>
#           </shape>
#         </transform>
#         <transform translation="0.9075736884683242 6.353015819278274 4.445828850292367e-16">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.878 0.4 0.2"/>
#             </appearance>
#             <sphere radius="1.32"/>
#           </shape>
#         </transform>
#         <transform translation="5.4454421308099485 1.8151473769366493 4.445828850292367e-16">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.878 0.4 0.2"/>
#             </appearance>
#             <sphere radius="1.32"/>
#           </shape>
#         </transform>
#         <transform translation="4.537868442341624 4.537868442341623 5.557286062865456e-16">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.878 0.4 0.2"/>
#             </appearance>
#             <sphere radius="1.32"/>
#           </shape>
#         </transform>
#         <transform translation="3.6302947538732995 7.260589507746598 6.668743275438549e-16">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.878 0.4 0.2"/>
#             </appearance>
#             <sphere radius="1.32"/>
#           </shape>
#         </transform>
#         <transform translation="8.168163196214921 2.722721065404974 6.668743275438547e-16">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.878 0.4 0.2"/>
#             </appearance>
#             <sphere radius="1.32"/>
#           </shape>
#         </transform>
#         <transform translation="7.260589507746597 5.445442130809948 7.780200488011639e-16">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.878 0.4 0.2"/>
#             </appearance>
#             <sphere radius="1.32"/>
#           </shape>
#         </transform>
#         <transform translation="6.353015819278269 8.168163196214921 8.891657700584727e-16">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.878 0.4 0.2"/>
#             </appearance>
#             <sphere radius="1.32"/>
#           </shape>
#         </transform>
#         <transform translation="0.9075736884683249 1.8151473769366495 1.435">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.878 0.4 0.2"/>
#             </appearance>
#             <sphere radius="1.32"/>
#           </shape>
#         </transform>
#         <transform translation="3.630294753873299 2.7227210654049743 1.4350000000000003">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.878 0.4 0.2"/>
#             </appearance>
#             <sphere radius="1.32"/>
#           </shape>
#         </transform>
#         <transform translation="2.722721065404974 5.4454421308099485 1.4350000000000003">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.878 0.4 0.2"/>
#             </appearance>
#             <sphere radius="1.32"/>
#           </shape>
#         </transform>
#         <transform translation="1.8151473769366493 8.168163196214921 1.4350000000000003">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.878 0.4 0.2"/>
#             </appearance>
#             <sphere radius="1.32"/>
#           </shape>
#         </transform>
#         <transform translation="6.353015819278274 3.6302947538732986 1.4350000000000005">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.878 0.4 0.2"/>
#             </appearance>
#             <sphere radius="1.32"/>
#           </shape>
#         </transform>
#         <transform translation="5.4454421308099485 6.353015819278274 1.4350000000000005">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.878 0.4 0.2"/>
#             </appearance>
#             <sphere radius="1.32"/>
#           </shape>
#         </transform>
#         <transform translation="4.537868442341624 0.0 1.435">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.878 0.4 0.2"/>
#             </appearance>
#             <sphere radius="1.32"/>
#           </shape>
#         </transform>
#         <transform translation="-2.7786430314327274e-16 4.537868442341623 1.435">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.878 0.4 0.2"/>
#             </appearance>
#             <sphere radius="1.32"/>
#           </shape>
#         </transform>
#         <transform translation="8.168163196214923 7.260589507746598 1.4350000000000007">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.878 0.4 0.2"/>
#             </appearance>
#             <sphere radius="1.32"/>
#           </shape>
#         </transform>
#         <transform translation="7.260589507746598 0.9075736884683236 1.4350

# %% [markdown]
# Some other examples, $\Sigma 3 (1\bar{-1}0)$ and $\Sigma 19 (111)$

# %%
struct_gb_2 = build.defect.grain_boundary(axis=[1,1,2], 
                        sigma=3, 
                        gb_plane=[1, -1, 0],
                        element='Fe',
                        graph=kg)

struct_gb_3 = build.defect.grain_boundary(axis=[1,1,1], 
                        sigma=19, 
                        gb_plane=[1, 1, 1],
                        element='Fe',
                        graph=kg)

# %% [markdown]
# **What are all the samples with symmetric tilt grain boundaries?**

# %%
res = kg.query_sample(kg.ontology.terms.pldo.SymmetricalTiltGrainBoundary)
res
# Out:
#                              AtomicScaleSample  \
# 0  sample:4878c894-b017-4e05-be07-6669c450888f
#
#                         SymmetricalTiltGrainBoundary
# 0  sample:4878c894-b017-4e05-be07-6669c450888f_Sy...

# %% [markdown]
# We see we have one structure in the database. We can also find what is the sigma value of this structure by modifying our query.

# %%
res = kg.query_sample([kg.ontology.terms.pldo.SymmetricalTiltGrainBoundary, 
                     kg.ontology.terms.pldo.hasSigmaValue])
res
# Out:
#                              AtomicScaleSample  \
# 0  sample:4878c894-b017-4e05-be07-6669c450888f
#
#                         SymmetricalTiltGrainBoundary hasSigmaValuevalue
# 0  sample:4878c894-b017-4e05-be07-6669c450888f_Sy...                  5

# %% [markdown]
# We can choose the sample, and save it

# %%
sample = res.AtomicScaleSample[0]
sample
# Out:
# rdflib.term.URIRef('sample:4878c894-b017-4e05-be07-6669c450888f')

# %%
kg.to_file(sample, filename="POSCAR", format="vasp")

# %%
! head -20 POSCAR
# Out:
# Fe
#  1.0000000000000000
#     18.1514737693664969   -0.0000000000000006    0.0000000000000000
#      0.0000000000000000    9.0757368846832485    0.0000000000000000
#      0.0000000000000011    0.0000000000000006    2.8699999999999997
#  Fe
#   40
# Cartesian
#   0.0000000000000000  0.0000000000000000  0.0000000000000000
#   2.7227210654049743  0.9075736884683246  0.0000000000000002
#   1.8151473769366497  3.6302947538732990  0.0000000000000003
#   0.9075736884683242  6.3530158192782737  0.0000000000000004
#   5.4454421308099485  1.8151473769366493  0.0000000000000004
#   4.5378684423416242  4.5378684423416233  0.0000000000000006
#   3.6302947538732995  7.2605895077465981  0.0000000000000007
#   8.1681631962149215  2.7227210654049738  0.0000000000000007
#   7.2605895077465972  5.4454421308099477  0.0000000000000008
#   6.3530158192782693  8.1681631962149215  0.0000000000000009
#   0.9075736884683249  1.8151473769366495  1.4350000000000001
#   3.6302947538732990  2.7227210654049743  1.4350000000000003
