# %% [markdown]
# ## VASP calculation

# %% [markdown]
# Read in an existing calculation to pyiron. Can also be a calculation done within pyiron

# %%
from atomrdf import KnowledgeGraph, System
from pyiron_atomistics import Project

# %%
pr = Project('t2')

# %% [markdown]
# Import the finished calculation; this can be ignored if the calculation is performed with pyiron|

# %%
pr.import_single_calculation('fccSi', copy_raw_files=True)
# Out:
# fccSi fccSi
# job was stored with the job ID  1201

# %%
pr.job_table()
# Out:
#      id    status chemicalformula    job  subjob projectpath  \
# 0  1201  finished              Si  fccSi  /fccSi        None
#
#                                                                                     project  \
# 0  /mnt/c/Users/menon/Documents/repos/projects-iuc17/atomRDF/examples/workflow_examples/t2/
#
#                    timestart timestop totalcputime          computer hamilton  \
# 0 2024-10-21 12:50:21.229226     None         None  pyiron@cmleo26#1     Vasp
#
#   hamversion parentid masterid
# 0       None     None     None

# %%
job = pr.load('fccSi')

# %%
kg = KnowledgeGraph()

# %%
kg.add_workflow(job, workflow_environment='pyiron')
# Out:
# 2024-10-21 12:50:31,196 - pyiron_log - WARNING - Could not access indices, returning None!
# 2024-10-21 12:50:31,308 - pyiron_log - WARNING - Could not access indices, returning None!

# %%
kg.visualise(workflow_view=True, layout='dot')
