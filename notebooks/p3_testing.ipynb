# %%
from rdflib import Graph
from pyscal_rdf import StructureGraph

# %%
g = StructureGraph(store="Oxigraph", )
h = StructureGraph(store="Oxigraph", store_file="example.db", identifier="a")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /mnt/c/Users/menon/Documents/winrepos/projects-iuc17/pyscal_rdf/pyscal_rdf/graph.py:79, in RDFGraph.__init__(self, graph_file, store, store_file, identifier)
#      78 try:
# ---> 79     prpath = store.path
#      80     dbfile = os.path.join(prpath, 'project.db')
#
# AttributeError: 'str' object has no attribute 'path'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 g = StructureGraph(store="Oxigraph", )
#       2 h = StructureGraph(store="Oxigraph", store_file="example.db", identifier="a")
#
# File /mnt/c/Users/menon/Documents/winrepos/projects-iuc17/pyscal_rdf/pyscal_rdf/structure.py:103, in StructureGraph.__init__(self, graph_file, store, store_file, identifier)
# ...

# %%
del h

# %%
k = StructureGraph(store="Oxigraph", store_file="example.db", identifier="b")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 k = StructureGraph(store="Oxigraph", store_file="example.db", identifier="b")
#
# File /mnt/c/Users/menon/Documents/winrepos/projects-iuc17/pyscal_rdf/pyscal_rdf/structure.py:103, in StructureGraph.__init__(self, graph_file, store, store_file, identifier)
#      98 def __init__(self, graph_file=None,
#      99     store="Memory",
#     100     store_file=None,
#     101     identifier="http://default_graph"):
# --> 103     super().__init__(graph_file=graph_file, store=store, store_file=store_file, identifier=identifier)
#     104     self._element_dict = element_dict
#     105     self._structure_dict = structure_dict
#
# File /mnt/c/Users/menon/Documents/winrepos/projects-iuc17/pyscal_rdf/pyscal_rdf/graph.py:67, in RDFGraph.__init__(self, graph_file, store, store_file, identifier)
# ...

# %%
sys = g.create.element.Ag()

# %%
g.visualise(backend='graphviz')

# %%
type(sys)
# Out:
# pyscal_rdf.rdfsystem.System
